# %% [markdown]
# # AL-OCR-Project
#
# Sophisticated Fintech OCR System for financial document intelligence, built with FastAPI, React, and AWS (S3/Textract). Features automated infrastructure via Terraform and CI/CD.
#
# **Repository:** https://github.com/Arisofia/AL-OCR-Project

# %%
# Clonar el repositorio AL-OCR-Project
# !git clone https://github.com/Arisofia/AL-OCR-Project.git

# %%
# Cambiar al directorio del proyecto
# %cd AL-OCR-Project
# !ls

# %%
# Instalar dependencias del backend (Python/FastAPI)
# !pip install -r src/requirements.txt
